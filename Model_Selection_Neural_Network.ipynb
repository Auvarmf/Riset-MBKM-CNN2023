# %% [markdown]
# <a href="https://colab.research.google.com/github/Auvarmf/Riset-MBKM-CNN2023/blob/main/Model_Selection_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install --upgrade tensorflow

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os
import csv
import pandas as pd
from google.colab import drive

# %%
# Mount Google Drive untuk mengakses file dan folder
drive.mount('MBKMCNN')
dataset = '/content/MBKMCNN/MyDrive/MBKMCNN'
folder1 = '/content/MBKMCNN/MyDrive/MBKMCNN/model_selection_neural_network/train/2017051002/face_2017051002_20221229_Pulang_26.png'
folder2 = '/content/MBKMCNN/MyDrive/MBKMCNN/model_selection_neural_network/train/2017051057/face_2017051057_20221227_Masuk_25.png'
# Out:
# Drive already mounted at MBKMCNN; to attempt to forcibly remount, call drive.mount("MBKMCNN", force_remount=True).

# %%
img1 = image.load_img(folder1)
img2 = image.load_img(folder2)

# %%
# Membuat subplot dengan 1 baris dan 2 kolom
plt.subplot(1, 2, 1)  # Subplot pertama (1 baris, 2 kolom, indeks 1)
plt.imshow(img1)
plt.title('Gambar 1')

plt.subplot(1, 2, 2)  # Subplot kedua (1 baris, 2 kolom, indeks 2)
plt.imshow(img2)
plt.title('Gambar 2')

plt.show()

# %%
cv2.imread(folder2).shape
# Out:
# (61, 61, 3)

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)

# %%
train_dataset = train.flow_from_directory('/content/MBKMCNN/MyDrive/MBKMCNN/model_selection_neural_network/train',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory('/content/MBKMCNN/MyDrive/MBKMCNN/model_selection_neural_network/validation',
                                                    target_size = (200,200),
                                                    batch_size = 3,
                                                    class_mode = 'binary')
# Out:
# Found 19 images belonging to 2 classes.
# Found 19 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3), activation = 'relu', input_shape = (200, 200, 3)),
                                    tf.keras.layers.MaxPool2D(2,2),

                                    tf.keras.layers.Conv2D(32,(3,3), activation = 'relu', input_shape = (200, 200, 3)),
                                    tf.keras.layers.MaxPool2D(2,2),

                                    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu', input_shape = (200, 200, 3)),
                                    tf.keras.layers.MaxPool2D(2,2),

                                    tf.keras.layers.Flatten(),

                                    tf.keras.layers.Dense(512, activation = 'relu'),

                                    tf.keras.layers.Dense(1, activation = 'sigmoid')
                                    ])

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
output_dir = '/content/MBKMCNN/MyDrive/MBKMCNN/model_selection_neural_network'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

results = []

# %%
# Loop untuk 10, 20, dan 50 epoch
for num_epochs in [10, 20, 50]:
    model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(200, 200, 3)),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Flatten(),
                                        tf.keras.layers.Dense(512, activation='relu'),
                                        tf.keras.layers.Dense(1, activation='sigmoid')
                                        ])

    model.compile(loss='binary_crossentropy',
                  optimizer=RMSprop(lr=0.001),
                  metrics=['accuracy'])

    # Melatih model
    model_fit = model.fit(train_dataset,
                          steps_per_epoch=len(train_dataset),
                          epochs=num_epochs,
                          validation_data=validation_dataset,
                          validation_steps=len(validation_dataset))

    # Mengambil akurasi dan loss terbaik
    best_accuracy = max(model_fit.history['val_accuracy'])
    best_loss = min(model_fit.history['val_loss'])

    # Menyimpan hasil akurasi dan loss terbaik dalam list
    results.append([num_epochs, best_accuracy, best_loss])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7a99513879a0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7a99513879a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7a99513879a0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7a99513879a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - ETA: 0s - loss: 2.9540 - accuracy: 0.2105
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7a9951387400> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7a9951387400>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7a9951387400> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7a9951387400>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - 5s 624ms/step - loss: 2.9540 - accuracy: 0.2105 - val_loss: 0.6062 - val_accuracy: 0.7368
# Epoch 2/10
# 7/7 [==============================] - 4s 617ms/step - loss: 0.5041 - accuracy: 0.7368 - val_loss: 1.4419 - val_accuracy: 0.5789
# Epoch 3/10
# 7/7 [==============================] - 6s 864ms/step - loss: 0.5383 - accuracy: 0.7368 - val_loss: 0.2984 - val_accuracy: 0.9474
# Epoch 4/10
# 7/7 [==============================] - 4s 581ms/step - loss: 0.2119 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 5/10
# 7/7 [==============================] - 4s 577ms/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 6/10
# 7/7 [==============================] - 5s 760ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 7/10
# 7/7 [==============================] - 6s 820ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 8/10
# 7/7 [==============================] - 5s 734ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 9/10
# 7/7 [==============================] - 4s 590ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 6.7163e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 7/7 [==============================] - 7s 1s/step - loss: 6.2690e-04 - accuracy: 1.0000 - val_loss: 4.3195e-04 - val_accuracy: 1.0000
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7a98e0f46200> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7a98e0f46200>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7a98e0f46200> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7a98e0f46200>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - ETA: 0s - loss: 2.9980 - accuracy: 0.5263
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7a98e10075b0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7a98e10075b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7a98e10075b0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7a98e10075b0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - 5s 549ms/step - loss: 2.9980 - accuracy: 0.5263 - val_loss: 0.6654 - val_accuracy: 1.0000
# Epoch 2/20
# 7/7 [==============================] - 4s 511ms/step - loss: 0.7887 - accuracy: 0.5263 - val_loss: 0.6454 - val_accuracy: 0.9474
# Epoch 3/20
# 7/7 [==============================] - 5s 859ms/step - loss: 0.8040 - accuracy: 0.7368 - val_loss: 0.4095 - val_accuracy: 1.0000
# Epoch 4/20
# 7/7 [==============================] - 4s 583ms/step - loss: 0.4124 - accuracy: 0.8421 - val_loss: 0.2812 - val_accuracy: 0.9474
# Epoch 5/20
# 7/7 [==============================] - 4s 569ms/step - loss: 0.1730 - accuracy: 0.9474 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 6/20
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 7/20
# 7/7 [==============================] - 5s 669ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 8/20
# 7/7 [==============================] - 5s 593ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 9/20
# 7/7 [==============================] - 6s 837ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 10/20
# 7/7 [==============================] - 6s 777ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 11/20
# 7/7 [==============================] - 4s 642ms/step - loss: 8.6928e-04 - accuracy: 1.0000 - val_loss: 5.2893e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 7/7 [==============================] - 6s 874ms/step - loss: 5.0598e-04 - accuracy: 1.0000 - val_loss: 3.6260e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 7/7 [==============================] - 4s 623ms/step - loss: 3.5470e-04 - accuracy: 1.0000 - val_loss: 2.5034e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 7/7 [==============================] - 5s 767ms/step - loss: 2.3950e-04 - accuracy: 1.0000 - val_loss: 1.8119e-04 - val_accuracy: 1.0000
# Epoch 15/20
# 7/7 [==============================] - 4s 578ms/step - loss: 1.7464e-04 - accuracy: 1.0000 - val_loss: 1.2812e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 7/7 [==============================] - 4s 624ms/step - loss: 1.2083e-04 - accuracy: 1.0000 - val_loss: 9.3256e-05 - val_accuracy: 1.0000
# Epoch 17/20
# 7/7 [==============================] - 6s 847ms/step - loss: 8.9375e-05 - accuracy: 1.0000 - val_loss: 6.6028e-05 - val_accuracy: 1.0000
# Epoch 18/20
# 7/7 [==============================] - 4s 539ms/step - loss: 6.0916e-05 - accuracy: 1.0000 - val_loss: 4.8676e-05 - val_accuracy: 1.0000
# Epoch 19/20
# 7/7 [==============================] - 6s 917ms/step - loss: 4.7071e-05 - accuracy: 1.0000 - val_loss: 3.6016e-05 - val_accuracy: 1.0000
# Epoch 20/20
# 7/7 [==============================] - 5s 741ms/step - loss: 3.4391e-05 - accuracy: 1.0000 - val_loss: 2.5887e-05 - val_accuracy: 1.0000
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7a98e0dc9870> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7a98e0dc9870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7a98e0dc9870> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7a98e0dc9870>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - ETA: 0s - loss: 1.6882 - accuracy: 0.6316
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7a98e0dc8a60> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7a98e0dc8a60>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7a98e0dc8a60> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7a98e0dc8a60>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 7/7 [==============================] - 5s 601ms/step - loss: 1.6882 - accuracy: 0.6316 - val_loss: 0.6302 - val_accuracy: 0.5789
# Epoch 2/50
# 7/7 [==============================] - 7s 939ms/step - loss: 0.6567 - accuracy: 0.5263 - val_loss: 0.5790 - val_accuracy: 0.6842
# Epoch 3/50
# 7/7 [==============================] - 7s 935ms/step - loss: 0.8463 - accuracy: 0.7895 - val_loss: 0.4863 - val_accuracy: 0.9474
# Epoch 4/50
# 7/7 [==============================] - 4s 588ms/step - loss: 0.5037 - accuracy: 0.7895 - val_loss: 0.2943 - val_accuracy: 1.0000
# Epoch 5/50
# 7/7 [==============================] - 4s 654ms/step - loss: 0.3082 - accuracy: 0.8947 - val_loss: 0.1838 - val_accuracy: 0.9474
# Epoch 6/50
# 7/7 [==============================] - 6s 891ms/step - loss: 0.1058 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 7/50
# 7/7 [==============================] - 4s 558ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 8/50
# 7/7 [==============================] - 5s 683ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 9/50
# 7/7 [==============================] - 6s 804ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 10/50
# 7/7 [==============================] - 4s 585ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 8.9609e-04 - val_accuracy: 1.0000
# Epoch 11/50
# 7/7 [==============================] - 5s 747ms/step - loss: 7.4484e-04 - accuracy: 1.0000 - val_loss: 5.5215e-04 - val_accuracy: 1.0000
# Epoch 12/50
# 7/7 [==============================] - 6s 842ms/step - loss: 4.9633e-04 - accuracy: 1.0000 - val_loss: 3.8325e-04 - val_accuracy: 1.0000
# Epoch 13/50
# 7/7 [==============================] - 4s 616ms/step - loss: 3.4788e-04 - accuracy: 1.0000 - val_loss: 2.4885e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 7/7 [==============================] - 5s 740ms/step - loss: 2.1224e-04 - accuracy: 1.0000 - val_loss: 1.7097e-04 - val_accuracy: 1.0000
# Epoch 15/50
# 7/7 [==============================] - 6s 814ms/step - loss: 1.5816e-04 - accuracy: 1.0000 - val_loss: 1.1103e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 7/7 [==============================] - 4s 629ms/step - loss: 9.9838e-05 - accuracy: 1.0000 - val_loss: 7.7256e-05 - val_accuracy: 1.0000
# Epoch 17/50
# 7/7 [==============================] - 4s 568ms/step - loss: 7.1431e-05 - accuracy: 1.0000 - val_loss: 5.6182e-05 - val_accuracy: 1.0000
# Epoch 18/50
# 7/7 [==============================] - 5s 779ms/step - loss: 5.1437e-05 - accuracy: 1.0000 - val_loss: 4.1638e-05 - val_accuracy: 1.0000
# Epoch 19/50
# 7/7 [==============================] - 6s 820ms/step - loss: 3.8091e-05 - accuracy: 1.0000 - val_loss: 2.8941e-05 - val_accuracy: 1.0000
# Epoch 20/50
# 7/7 [==============================] - 4s 516ms/step - loss: 2.7433e-05 - accuracy: 1.0000 - val_loss: 2.1852e-05 - val_accuracy: 1.0000
# Epoch 21/50
# 7/7 [==============================] - 4s 575ms/step - loss: 2.0166e-05 - accuracy: 1.0000 - val_loss: 1.6493e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 7/7 [==============================] - 6s 842ms/step - loss: 1.5502e-05 - accuracy: 1.0000 - val_loss: 1.2544e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 7/7 [==============================] - 4s 569ms/step - loss: 1.1902e-05 - accuracy: 1.0000 - val_loss: 9.7770e-06 - val_accuracy: 1.0000
# Epoch 24/50
# 7/7 [==============================] - 5s 662ms/step - loss: 9.1245e-06 - accuracy: 1.0000 - val_loss: 7.8201e-06 - val_accuracy: 1.0000
# Epoch 25/50
# 7/7 [==============================] - 6s 814ms/step - loss: 7.2356e-06 - accuracy: 1.0000 - val_loss: 6.1469e-06 - val_accuracy: 1.0000
# Epoch 26/50
# 7/7 [==============================] - 4s 561ms/step - loss: 5.8373e-06 - accuracy: 1.0000 - val_loss: 5.1381e-06 - val_accuracy: 1.0000
# Epoch 27/50
# 7/7 [==============================] - 4s 519ms/step - loss: 4.8827e-06 - accuracy: 1.0000 - val_loss: 4.2995e-06 - val_accuracy: 1.0000
# Epoch 28/50
# 7/7 [==============================] - 5s 801ms/step - loss: 4.1144e-06 - accuracy: 1.0000 - val_loss: 3.6770e-06 - val_accuracy: 1.0000
# Epoch 29/50
# 7/7 [==============================] - 6s 808ms/step - loss: 3.5562e-06 - accuracy: 1.0000 - val_loss: 3.2379e-06 - val_accuracy: 1.0000
# Epoch 30/50
# 7/7 [==============================] - 4s 575ms/step - loss: 3.1453e-06 - accuracy: 1.0000 - val_loss: 2.8997e-06 - val_accuracy: 1.0000
# Epoch 31/50
# 7/7 [==============================] - 6s 846ms/step - loss: 2.7982e-06 - accuracy: 1.0000 - val_loss: 2.5669e-06 - val_accuracy: 1.0000
# Epoch 32/50
# 7/7 [==============================] - 4s 561ms/step - loss: 2.4923e-06 - accuracy: 1.0000 - val_loss: 2.3314e-06 - val_accuracy: 1.0000
# Epoch 33/50
# 7/7 [==============================] - 4s 692ms/step - loss: 2.2516e-06 - accuracy: 1.0000 - val_loss: 2.1126e-06 - val_accuracy: 1.0000
# Epoch 34/50
# 7/7 [==============================] - 6s 895ms/step - loss: 2.0686e-06 - accuracy: 1.0000 - val_loss: 1.8933e-06 - val_accuracy: 1.0000
# Epoch 35/50
# 7/7 [==============================] - 4s 575ms/step - loss: 1.8619e-06 - accuracy: 1.0000 - val_loss: 1.7665e-06 - val_accuracy: 1.0000
# Epoch 36/50
# 7/7 [==============================] - 4s 585ms/step - loss: 1.7320e-06 - accuracy: 1.0000 - val_loss: 1.6497e-06 - val_accuracy: 1.0000
# Epoch 37/50
# 7/7 [==============================] - 5s 792ms/step - loss: 1.6167e-06 - accuracy: 1.0000 - val_loss: 1.5349e-06 - val_accuracy: 1.0000
# Epoch 38/50
# 7/7 [==============================] - 6s 824ms/step - loss: 1.5051e-06 - accuracy: 1.0000 - val_loss: 1.4205e-06 - val_accuracy: 1.0000
# Epoch 39/50
# 7/7 [==============================] - 4s 646ms/step - loss: 1.4013e-06 - accuracy: 1.0000 - val_loss: 1.3465e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 7/7 [==============================] - 7s 1s/step - loss: 1.3272e-06 - accuracy: 1.0000 - val_loss: 1.2767e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 7/7 [==============================] - 7s 961ms/step - loss: 1.2643e-06 - accuracy: 1.0000 - val_loss: 1.2166e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 7/7 [==============================] - 4s 582ms/step - loss: 1.2030e-06 - accuracy: 1.0000 - val_loss: 1.1591e-06 - val_accuracy: 1.0000
# Epoch 43/50
# 7/7 [==============================] - 5s 707ms/step - loss: 1.1480e-06 - accuracy: 1.0000 - val_loss: 1.1073e-06 - val_accuracy: 1.0000
# Epoch 44/50
# 7/7 [==============================] - 6s 882ms/step - loss: 1.0936e-06 - accuracy: 1.0000 - val_loss: 1.0617e-06 - val_accuracy: 1.0000
# Epoch 45/50
# 7/7 [==============================] - 4s 583ms/step - loss: 1.0443e-06 - accuracy: 1.0000 - val_loss: 1.0124e-06 - val_accuracy: 1.0000
# Epoch 46/50
# 7/7 [==============================] - 6s 849ms/step - loss: 9.9940e-07 - accuracy: 1.0000 - val_loss: 9.7153e-07 - val_accuracy: 1.0000
# Epoch 47/50
# 7/7 [==============================] - 4s 584ms/step - loss: 9.6158e-07 - accuracy: 1.0000 - val_loss: 9.3069e-07 - val_accuracy: 1.0000
# Epoch 48/50
# 7/7 [==============================] - 5s 673ms/step - loss: 9.2445e-07 - accuracy: 1.0000 - val_loss: 8.9746e-07 - val_accuracy: 1.0000
# Epoch 49/50
# 7/7 [==============================] - 6s 911ms/step - loss: 8.8764e-07 - accuracy: 1.0000 - val_loss: 8.5843e-07 - val_accuracy: 1.0000
# Epoch 50/50
# 7/7 [==============================] - 4s 634ms/step - loss: 8.5330e-07 - accuracy: 1.0000 - val_loss: 8.3046e-07 - val_accuracy: 1.0000

# %%
# Menyimpan hasil dalam file CSV
output_file = os.path.join(output_dir, 'training_results.csv')
with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Epochs', 'Best Accuracy', 'Best Loss'])
    writer.writerows(results)

# Menyimpan hasil dalam DataFrame
results_df = pd.DataFrame(results, columns=['Epochs', 'Best Accuracy', 'Best Loss'])

# Menampilkan DataFrame
results_df
# Out:
#    Epochs  Best Accuracy     Best Loss
# 0      10            1.0  4.319480e-04
# 1      20            1.0  2.588734e-05
# 2      50            1.0  8.304627e-07
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(results_df, *['Epochs'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(results_df, *['Best Loss'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(results_df, *['Epochs'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(results_df, *['Best Loss'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(results_df, *[[['Epochs', 'Best Loss']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(results_df, *['Epochs', 'Best Loss', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(results_df, *['Epochs', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(results_df, *['Best Accuracy', 'Best Loss', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(results_df, *['Best Accuracy', 'count()', None], **{})
# chart
